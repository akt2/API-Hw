# %%
import json
import csv
import requests
import matplotlib.pyplot as plt
import openweathermapy as ow
import pandas as pd
import numpy as np
import time
from config import api
from citipy import citipy

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"


query_url = f"{url}appid={api}&units={units}&q="

# %%
# grab 500 random cities, loop them through the query

# %% [markdown]
# ## Cities list

# %%
lar=(-90,90)
lor=(-180,180)
lalo=[]
cities=[]

la=np.random.uniform(low=-90.000,high=90.000,size=1500)
lo=np.random.uniform(low=-180.000,high=180.000,size=1500)
lalo=zip(la,lo)

for x in lalo:
    city=citipy.nearest_city(x[0],x[1]).city_name
    if city not in cities:
        cities.append(city)

# %%
type(cities)
cities

lat = []
temp = []

for city in cities:
    response=requests.get(query_url + 'city').json()
    temp.append(response['main']['temp'])

# %%
temp
# I don't even know what's happening. I'm going to bed.
# Out:
# [18.68,
#  18.68,
#  18.68,
#  18.68,
#  18.68,
#  18.68,
#  18.68,
#  18.68,
#  18.68,
#  18.68,
#  18.68,
#  18.68,
#  18.68,
#  18.68,
#  18.68,
#  18.68,
#  18.68,
#  18.68,
#  18.68,
#  18.68,
#  18.68,
#  18.68,
#  18.68,
#  18.68,
#  18.68,
#  18.68,
#  18.68,
#  18.68,
#  18.68,
#  18.68,
#  18.68,
#  18.68,
#  18.68,
#  18.68,
#  18.68,
#  18.68,
#  18.68,
#  18.68,
#  18.68,
#  18.68,
#  18.68,
#  18.68,
#  18.68,
#  18.68,
#  18.68,
#  18.68,
#  18.68,
#  18.68,
#  18.68,
#  18.68,
#  18.68,
#  18.68,
#  18.68,
#  18.68,
#  18.68,
#  18.68,
#  18.68,
#  18.68,
#  18.68,
#  18.68,
#  18.68,
#  18.68,
#  18.68,
#  18.68,
#  18.68,
#  18.68,
#  18.68,
#  18.68,
#  18.68,
#  18.68,
#  18.68,
#  18.68,
#  18.68,
#  18.68,
#  18.68,
#  18.68,
#  18.68,
#  18.68,
#  18.68,
#  18.68,
#  18.68,
#  18.68,
#  18.68,
#  18.68,
#  18.68,
#  18.68,
#  18.68,
#  18.68,
#  18.68,
#  18.68,
#  18.68,
#  18.68,
#  18.68,
#  18.68,
#  18.68,
#  18.68,
#  18.68,
#  18.68,
#  18.68,
#  18.68,
# ...

# %% [markdown]
# ## Loop

# %%
y=10
data=ow.get_current(cities[y],**settings)
data
# Out:
# {'coord': {'lon': 0.34, 'lat': 46.58},
#  'weather': [{'id': 800,
#    'main': 'Clear',
#    'description': 'clear sky',
#    'icon': '01n'}],
#  'base': 'stations',
#  'main': {'temp': 3.28,
#   'pressure': 1028,
#   'humidity': 86,
#   'temp_min': 2.22,
#   'temp_max': 4.44},
#  'visibility': 10000,
#  'wind': {'speed': 4.1, 'deg': 340},
#  'clouds': {'all': 0},
#  'dt': 1553488030,
#  'sys': {'type': 1,
#   'id': 6460,
#   'message': 0.0041,
#   'country': 'FR',
#   'sunrise': 1553493157,
#   'sunset': 1553537801},
#  'id': 2986495,
#  'name': 'Poitiers',
#  'cod': 200}

# %%
wd=[]
settings={'units':'metric','appid':api}
summary = ['main.temp','main.humidity','wind.speed','clouds.all','coord.lon','coord.lat']
for index in range(len(cities)):
    try:
        wd=ow.get_current(cities[index],**settings)
    except:
        print('blob')
# Out:
# blob
# blob
# blob
# blob
# blob
# blob
# blob
# blob
# blob
# blob
# blob
# blob
# blob
# blob
# blob
# blob
# blob
# blob
# blob
# blob
# blob
# blob
# blob
# blob
# blob
# blob
# blob
# blob
# blob
# blob
# blob
# blob
# blob
# blob
# blob
# blob
# blob
# blob
# blob
# blob
# blob
# blob
# blob
# blob
# blob
# blob
# blob
# blob
# blob
# blob
# blob
# blob
# blob
# blob
# blob
# blob
# blob
# blob
# blob
# blob
# blob
# blob

# %%
#WHY ISN'T THIS WORKING
# it won't stop
# it just keeps going
# how do i make it stop
# interrupting kernel doesn't work
# whyyyyyyyyyyy

# %%
Station=[]
Longitude=[]
Latitude=[]
Temperature=[]
Humidity=[]
Cloudiness=[]
WindSpeed=[]

for city in cities:
    try:
        response=requests.get(f'http:/api.openweathermap.org/data/2.5/weather?unites=metric&APPID=e8ff4dc16ded49839a8062b35ad74300&q={city}').json()
        Station.append(response['name'])
        Longitude.append(response['coord']['lon'])
        Latitude.append(response['coord']['lat'])
        Temperature.append(response['main']['temp'])
        Humidity.append(response['main']['humidity'])
        Cloudiness.append(response['clouds']['all'])
        WindSpeed.append(response['wind']['speed'])
        time.sleep(2)
    except:
        print('Bob is flailing...')
    continue
# Out:
# Bob is flailing...
# Bob is flailing...
# Bob is flailing...
# Bob is flailing...
# Bob is flailing...
# Bob is flailing...
# Bob is flailing...
# Bob is flailing...
# Bob is flailing...
# Bob is flailing...
# Bob is flailing...
# Bob is flailing...
# Bob is flailing...
# Bob is flailing...
# Bob is flailing...
# Bob is flailing...
# Bob is flailing...
# Bob is flailing...
# Bob is flailing...
# Bob is flailing...
# Bob is flailing...
# Bob is flailing...
# Bob is flailing...
# Bob is flailing...
# Bob is flailing...
# Bob is flailing...
# Bob is flailing...
# Bob is flailing...
# Bob is flailing...
# Bob is flailing...
# Bob is flailing...
# Bob is flailing...
# Bob is flailing...
# Bob is flailing...
# Bob is flailing...
# Bob is flailing...
# Bob is flailing...
# Bob is flailing...
# Bob is flailing...
# Bob is flailing...
# Bob is flailing...
# Bob is flailing...
# Bob is flailing...
# Bob is flailing...
# Bob is flailing...
# Bob is flailing...
# Bob is flailing...
# ...

# %%
# Bob is indeed flailing.

# %%
# Print log? wut why
# To see Bob flail

# %%
Station=[]
Longitude=[]
Latitude=[]
Temperature=[]
Humidity=[]
Cloudiness=[]
WindSpeed=[]

for city in cities:
    response=requests.get(f'http:/api.openweathermap.org/data/2.5/weather?unites=metric&APPID=e8ff4dc16ded49839a8062b35ad74300&q={city}').json()
    Station.append(response['name'])
    Longitude.append(response['coord']['lon'])
    Latitude.append(response['coord']['lat'])
    Temperature.append(response['main']['temp'])
    Humidity.append(response['main']['humidity'])
    Cloudiness.append(response['clouds']['all'])
    WindSpeed.append(response['wind']['speed'])
    time.sleep(2)
# Out:
# ---------------------------------------------------------------------------
# MissingSchema                             Traceback (most recent call last)
# <ipython-input-171-b466891c1c62> in <module>
#       8
#       9 for city in cities:
# ---> 10     response=requests.get(f'http:/api.openweathermap.org/data/2.5/weather?unites=metric&APPID=e8ff4dc16ded49839a8062b35ad74300&q={city}').json()
#      11     Station.append(response['name'])
#      12     Longitude.append(response['coord']['lon'])
#
# ~\Anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~\Anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ...

# %%
# let's follow the recommendation
Station=[]
Longitude=[]
Latitude=[]
Temperature=[]
Humidity=[]
Cloudiness=[]
WindSpeed=[]

for city in cities:
    response=requests.get(f'http://http:/api.openweathermap.org/data/2.5/weather?unites=metric&APPID=e8ff4dc16ded49839a8062b35ad74300&q=rikitea?').json()
    Station.append(response['name'])
    Longitude.append(response['coord']['lon'])
    Latitude.append(response['coord']['lat'])
    Temperature.append(response['main']['temp'])
    Humidity.append(response['main']['humidity'])
    Cloudiness.append(response['clouds']['all'])
    WindSpeed.append(response['wind']['speed'])
    time.sleep(2)

# Not helpful
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     158             conn = connection.create_connection(
# --> 159                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     160
#
# ~\Anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      56
# ---> 57     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      58         af, socktype, proto, canonname, sa = res
#
# ~\Anaconda3\lib\socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     747     addrlist = []
# --> 748     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     749         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 11001] getaddrinfo failed
#
# ...

# %%
location=(-110.01,27.52)
data=ow.get_current(location,units='metric')
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-162-7fdc7f678800> in <module>
#       1 location=(-110.01,27.52)
# ----> 2 data=ow.get_current(location,units='metric')
#
# ~\Anaconda3\lib\site-packages\openweathermapy\core.py in get_current(city, **params)
#     153            >>> data = get_current(zip="34128,DE")
#     154 	"""
# --> 155         data = wrap_get("weather")(city, **params)
#     156         return DataPoint(data)
#     157
#
# ~\Anaconda3\lib\site-packages\openweathermapy\core.py in call(loc, **params)
#      97                 if settings:
#      98                         params.update(settings)
# ---> 99                 data = get(url, **params)
#     100                 if converter:
#     101                         data = converter(data)
#
# ~\Anaconda3\lib\site-packages\openweathermapy\core.py in get(url, **params)
# ...

# %% [markdown]
# ##YAY

# %%
wd.columns=['Temperature','Humidity','Wind Speed','Cloudiness','Longitude','Latitude']
# col=wd.columns.tolist()
# cols=col[:-2]+col[-1:]+col[4:-1]
# wd=wd[cols]

# %%
wd.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-175-4209b8b1f93c> in <module>
# ----> 1 wd.head()
#
# AttributeError: 'NestedDict' object has no attribute 'head'

# %%
x=wd['Latitude']
y=wd['Temperature']
plt.scatter(x,y)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-176-4f0cda6f8cf0> in <module>
# ----> 1 x=wd['Latitude']
#       2 y=wd['Temperature']
#       3 plt.scatter(x,y)
#
# KeyError: 'Latitude'

# %%
plt.xlabel('Latitude')
plt.ylabel('Temperature (C)')
plt.title('Temperature vs Latitude (24/03/2019)')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-172-f8e0ebecebbc> in <module>
# ----> 1 x=wd['Latitude']
#       2 y=wd['Temperature']
#       3 plt.scatter(x,y)
#       4 plt.xlabel('Latitude')
#       5 plt.ylabel('Temperature (C)')
#
# KeyError: 'Latitude'
